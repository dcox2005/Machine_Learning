# %% [markdown]
# # Testing the logistic regression using various real-world data sets.
#
# ## Author: Bojian Xu, bojianxu@ewu.edu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import logistic_regression as logic
import sys
sys.path.append('..')
from code_misc.utils import MyUtils

# %%
data_set = 'ionosphere'

print(data_set+'/'+'hello')
# Out:
# ionosphere/hello

# %%
# READ in data
df_X_train = pd.read_csv(data_set+'/'+'X_train.csv', header=None)
df_y_train = pd.read_csv(data_set+'/'+'y_train.csv', header=None)
df_X_test = pd.read_csv(data_set+'/'+'X_test.csv', header=None)
df_y_test = pd.read_csv(data_set+'/'+'y_test.csv', header=None)

# save in numpy arrays
X_train = df_X_train.to_numpy()
y_train = df_y_train.to_numpy()
X_test = df_X_test.to_numpy()
y_test = df_y_test.to_numpy()

# get training set size
n_train = X_train.shape[0]

# normalize all features to [0,1] or [-1,1]
if data_set == 'ionosphere':
    X_all = MyUtils.normalize_neg1_pos1(np.concatenate((X_train, X_test), axis=0))


X_train = X_all[:n_train]
X_test = X_all[n_train:]

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
#print(y_test)
# Out:
# (280, 34)
# (280, 1)
# (71, 34)
# (71, 1)

# %%
#print(y_train[-10:])

# %%
# build the model
log = logic.LogisticRegression()

# %%
# train the model
# log.fit(X_train, y_train, lam = 0, eta = 0.1, iterations = 5000, SGD = False, mini_batch_size = 20, degree = 2)
log.fit(X_train, y_train, lam = 0, eta = 0.1, iterations = 100, SGD = True, mini_batch_size = 20, degree = 1)

# %%
print('misclassfied percentage from training: ', log.error(X_train, y_train)/X_train.shape[0])
print('misclassfied percentage from validation: ', log.error(X_test, y_test)/X_test.shape[0])
# Out:
# misclassfied percentage from training:  0.010714285714285714
# misclassfied percentage from validation:  0.04225352112676056

# %%
preds = log.predict(X_test)

# %%
for i in range(y_test.shape[0]):
    print('test sample ', i)
    if np.sign(preds[i]-0.5) != y_test[i]:
        print('misclassified!!')
    print('predicted probablity of being +1 is: ', preds[i])
    print('label is', y_test[i])
    print('\n')
# Out:
# test sample  0
# predicted probablity of being +1 is:  [0.99880141]
# label is [1.]
#
#
# test sample  1
# predicted probablity of being +1 is:  [0.99746724]
# label is [1.]
#
#
# test sample  2
# predicted probablity of being +1 is:  [0.3810809]
# label is [-1.]
#
#
# test sample  3
# predicted probablity of being +1 is:  [0.94802683]
# label is [1.]
#
#
# test sample  4
# predicted probablity of being +1 is:  [0.99999237]
# label is [1.]
#
#
# test sample  5
# predicted probablity of being +1 is:  [0.99599334]
# label is [1.]
#
#
# test sample  6
# predicted probablity of being +1 is:  [0.99880093]
# label is [1.]
#
#
# test sample  7
# predicted probablity of being +1 is:  [0.96338326]
# label is [1.]
#
#
# test sample  8
# predicted probablity of being +1 is:  [0.00437655]
# label is [-1.]
#
#
# test sample  9
# predicted probablity of being +1 is:  [1.26960512e-06]
# label is [-1.]
#
#
# test sample  10
# predicted probablity of being +1 is:  [0.99995817]
# label is [1.]
#
#
# test sample  11
# predicted probablity of being +1 is:  [0.99951881]
# label is [1.]
#
#
# test sample  12
# predicted probablity of being +1 is:  [0.003149]
# label is [-1.]
#
#
# test sample  13
# predicted probablity of being +1 is:  [0.99947605]
# label is [1.]
#
#
# test sample  14
# predicted probablity of being +1 is:  [0.99949558]
# label is [1.]
#
#
# test sample  15
# predicted probablity of being +1 is:  [8.09970923e-05]
# label is [-1.]
#
#
# test sample  16
# predicted probablity of being +1 is:  [0.99612239]
# label is [1.]
#
#
# test sample  17
# predicted probablity of being +1 is:  [0.00058139]
# label is [-1.]
#
#
# test sample  18
# predicted probablity of being +1 is:  [0.93011047]
# label is [1.]
#
#
# test sample  19
# predicted probablity of being +1 is:  [0.99955627]
# label is [1.]
#
#
# test sample  20
# predicted probablity of being +1 is:  [0.18133914]
# label is [-1.]
#
#
# test sample  21
# predicted probablity of being +1 is:  [0.00057318]
# label is [-1.]
#
#
# test sample  22
# predicted probablity of being +1 is:  [0.99964806]
# label is [1.]
#
#
# test sample  23
# predicted probablity of being +1 is:  [0.99909909]
# label is [1.]
#
#
# test sample  24
# predicted probablity of being +1 is:  [0.99859002]
# label is [1.]
#
#
# test sample  25
# predicted probablity of being +1 is:  [0.99988003]
# label is [1.]
#
#
# test sample  26
# predicted probablity of being +1 is:  [0.99993305]
# label is [1.]
#
#
# test sample  27
# predicted probablity of being +1 is:  [0.96976336]
# label is [1.]
#
#
# test sample  28
# predicted probablity of being +1 is:  [0.00020176]
# label is [-1.]
#
#
# test sample  29
# predicted probablity of being +1 is:  [0.99895947]
# label is [1.]
#
#
# test sample  30
# predicted probablity of being +1 is:  [6.9721055e-10]
# label is [-1.]
#
#
# test sample  31
# misclassified!!
# predicted probablity of being +1 is:  [0.89903332]
# label is [-1.]
#
#
# test sample  32
# misclassified!!
# predicted probablity of being +1 is:  [0.6279592]
# label is [-1.]
#
#
# test sample  33
# predicted probablity of being +1 is:  [0.99977311]
# label is [1.]
#
#
# test sample  34
# predicted probablity of being +1 is:  [3.40697816e-05]
# label is [-1.]
#
#
# test sample  35
# predicted probablity of being +1 is:  [0.99951408]
# label is [1.]
#
#
# test sample  36
# predicted probablity of being +1 is:  [0.99999962]
# label is [1.]
#
#
# test sample  37
# predicted probablity of being +1 is:  [0.99831744]
# label is [1.]
#
#
# test sample  38
# predicted probablity of being +1 is:  [8.09824575e-05]
# label is [-1.]
#
#
# test sample  39
# predicted probablity of being +1 is:  [0.99907955]
# label is [1.]
#
#
# test sample  40
# predicted probablity of being +1 is:  [0.15812563]
# label is [-1.]
#
#
# test sample  41
# predicted probablity of being +1 is:  [0.98782076]
# label is [1.]
#
#
# test sample  42
# predicted probablity of being +1 is:  [1.48309653e-05]
# label is [-1.]
#
#
# test sample  43
# predicted probablity of being +1 is:  [0.96802459]
# label is [1.]
#
#
# test sample  44
# predicted probablity of being +1 is:  [0.97754419]
# label is [1.]
#
#
# test sample  45
# predicted probablity of being +1 is:  [0.94787018]
# label is [1.]
#
#
# test sample  46
# misclassified!!
# predicted probablity of being +1 is:  [0.57057381]
# label is [-1.]
#
#
# test sample  47
# predicted probablity of being +1 is:  [0.00027789]
# label is [-1.]
#
#
# test sample  48
# predicted probablity of being +1 is:  [0.99982144]
# label is [1.]
#
#
# test sample  49
# predicted probablity of being +1 is:  [0.00530564]
# label is [-1.]
#
#
# test sample  50
# predicted probablity of being +1 is:  [0.99559872]
# label is [1.]
#
#
# test sample  51
# predicted probablity of being +1 is:  [0.999998]
# label is [1.]
#
#
# test sample  52
# predicted probablity of being +1 is:  [7.837309e-05]
# label is [-1.]
#
#
# test sample  53
# predicted probablity of being +1 is:  [0.99750288]
# label is [1.]
#
#
# test sample  54
# predicted probablity of being +1 is:  [0.99184285]
# label is [1.]
#
#
# test sample  55
# predicted probablity of being +1 is:  [5.11888414e-09]
# label is [-1.]
#
#
# test sample  56
# predicted probablity of being +1 is:  [0.75659209]
# label is [1.]
#
#
# test sample  57
# predicted probablity of being +1 is:  [0.94228232]
# label is [1.]
#
#
# test sample  58
# predicted probablity of being +1 is:  [0.996996]
# label is [1.]
#
#
# test sample  59
# predicted probablity of being +1 is:  [0.99672329]
# label is [1.]
#
#
# test sample  60
# predicted probablity of being +1 is:  [0.99570843]
# label is [1.]
#
#
# test sample  61
# predicted probablity of being +1 is:  [0.99944077]
# label is [1.]
#
#
# test sample  62
# predicted probablity of being +1 is:  [2.20787061e-07]
# label is [-1.]
#
#
# test sample  63
# predicted probablity of being +1 is:  [0.02242786]
# label is [-1.]
#
#
# test sample  64
# predicted probablity of being +1 is:  [0.01497074]
# label is [-1.]
#
#
# test sample  65
# predicted probablity of being +1 is:  [0.99150747]
# label is [1.]
#
#
# test sample  66
# predicted probablity of being +1 is:  [0.99335958]
# label is [1.]
#
#
# test sample  67
# predicted probablity of being +1 is:  [0.28560282]
# label is [-1.]
#
#
# test sample  68
# predicted probablity of being +1 is:  [0.99995581]
# label is [1.]
#
#
# test sample  69
# predicted probablity of being +1 is:  [4.85917316e-05]
# label is [-1.]
#
#
# test sample  70
# predicted probablity of being +1 is:  [6.33516692e-08]
# label is [-1.]
